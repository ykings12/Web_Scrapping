# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page-1').text

# %%
#headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'} -requests.get('url',headers=headers).text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
#print(soup.prettify())

# %%
#soup.find_all('h1')[0].text

# %%
#for i in soup.find_all('h2'):
    #print(i.text.strip())

# %%
#for i in soup.find_all('p',class_='rating'):
    #print(i.text.strip())

# %%
#for i in soup.find_all('a',class_='review-count'):
    #print(i.text.strip())

# %%
#for i in soup.find_all('a',class_='ab_chip'):
    #print(i.text.strip())

# %%
company=soup.find_all('div',class_='company-content-wrapper')

# %%
len(company)
# Out:
# 30

# %%
name=[]  # empty list to store the name of companies further
rating=[]
reviews=[]
ctype=[]
hq=[]
old=[]
employees=[]


for i in company:
    rating.append(i.find('p',class_='rating').text.strip())
    name.append(i.find('h2').text.strip())
    reviews.append(i.find('a',class_='review-count').text.strip())
    ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
    hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
    old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
    employees.append(i.find_all('p',class_='infoEntity')[3].text.strip())
    
    #try:
      #  employees.append(i.find_all('p',class_='infoEntity')[3].text.strip())
    #except:
       # employees.append(np.nan)
    
d={'name':name,'rating':rating, 'reviews':reviews, 'type':ctype, 'hq':hq, 'old':old,'employees':employees}    
df=pd.DataFrame(d)
df
# Out:
#                    name rating          reviews     type  \
# 0                   TCS    3.9  (44.8k Reviews)   Public
# 1             Accenture    4.2  (30.2k Reviews)   Public
# 2             Cognizant    4.0  (27.3k Reviews)  Private
# 3            ICICI Bank    4.0  (32.9k Reviews)   Public
# 4             HDFC Bank    4.0  (36.9k Reviews)   Public
# 5               Infosys    4.0  (26.1k Reviews)   Public
# 6                 Wipro    3.9  (26.2k Reviews)   Public
# 7             Capgemini    4.0  (22.2k Reviews)   Public
# 8         Tech Mahindra    3.8  (20.2k Reviews)   Public
# 9               Genpact    4.0  (19.7k Reviews)   Public
# 10     HCL Technologies    3.9  (16.8k Reviews)   Public
# 11            Axis Bank    3.9  (17.9k Reviews)   Public
# 12               Amazon    4.2  (16.1k Reviews)   Public
# 13                  IBM    4.2  (20.3k Reviews)   Public
# 14  Concentrix Corpo...    4.1  (14.5k Reviews)   Public
# 15  Larsen & Toubro ...    4.1  (23.4k Reviews)   Public
# 16         Reliance jio    4.0  (13.9k Reviews)   Public
# 17        Vodafone Idea    4.2  (13.5k Reviews)   Public
# 18  HDB Financial Se...    4.0  (12.5k Reviews)  Private
# 19      Teleperformance    3.6  (13.5k Reviews)  Private
# 20  Kotak Mahindra B...    3.9  (12.9k Reviews)   Public
# 13     1 Lakh+ Employees (India)
# 14     10k-50k Employees (India)
# 15     10k-50k Employees (India)
# 16  50k-1 Lakh Employees (India)
# 17     10k-50k Employees (India)
# 18     1 Lakh+ Employees (India)
# 19  50k-1 Lakh Employees (India)
# 20  50k-1 Lakh Employees (India)
# 21     10k-50k Employees (India)
# 22     1 Lakh+ Employees (India)
# 23  50k-1 Lakh Employees (India)
# 24     10k-50k Employees (India)
# 25     1 Lakh+ Employees (India)
# 26     10k-50k Employees (India)
# 27     10k-50k Employees (India)
# 28     1 Lakh+ Employees (India)
# 29  50k-1 Lakh Employees (India)

# %%
old
# Out:
# ['Public',
#  'Public',
#  'Private',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Private',
#  'Private',
#  'Public',
#  'Public',
#  'Public',
#  'Private',
#  'Public',
#  'Private',
#  'Private',
#  'Public',
#  'Public',
#  'Public']

# %%
company[0].find_all('p',class_='infoEntity')[0].text.strip()
# Out:
# 'Public'

# %% [markdown]
# ## DataFrame for all the pages

# %%
final =pd.DataFrame()

for j in range(1,11):
    url='https://www.ambitionbox.com/list-of-companies?page-{}'.format(j)
    webpage=requests.get(url).text
    soup=BeautifulSoup(webpage,'lxml')
    company=soup.find_all('div',class_='company-content-wrapper')
    name=[]
    rating=[]
    reviews=[]
    ctype=[]
    hq=[]
    how_old=[]
    employees=[]
    
    for i in company:
        
        try:
            name.append(i.find('h2').text.strip())
        except:
            name.append(np.nan)

        try:
            rating.append(i.find('p',class_='rating').text.strip())
        except:
            rating.append(np.nan)
   
        try:
            reviews.append(i.find('a' , class_='review-count').text.strip())
        except:
            reviews.append(np.nan)

        try:
            ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
        except:
            ctype.append(np.nan)
        try:
            hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
        except:
            hq.append(np.nan)
    
        try:
            how_old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
        except:
            how_old.append(np.nan)
        
        try:
            employees.append(i.find_all('p',class_='infoEntity')[3].text.strip())
        except:
            employees.append(np.nan)
        
        
    
    df=pd.DataFrame({'name':name,
    'rating':rating,
    'reviews':reviews,
    'company_type':ctype,
    'Head_Quarters':hq,
    'Company_Age':how_old,
    'No_of_Employees':employees,
    })
  
    final=final.append(df,ignore_index=True)
# Out:
# C:\Users\yashs\AppData\Local\Temp\ipykernel_14620\1764701877.py:63: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df,ignore_index=True)

# %%
df.shape
# Out:
# (30, 7)

# %%
final.shape
# Out:
# (300, 7)
